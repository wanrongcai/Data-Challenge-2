# %%
import numpy as np
import pandas as pd 
from pandas.core.frame import DataFrame

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

# %%
data_origin=data_origin[[0]]

for i in range(50000,100000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

print(df)
# Out:
#       accountNumber customerId creditLimit availableMoney  \
# 0         246251253  246251253      5000.0         624.04
# 1         246251253  246251253      5000.0         271.42
# 2         246251253  246251253      5000.0        1677.46
# 3         246251253  246251253      5000.0         1574.7
# 4         246251253  246251253      5000.0         1533.2
# ...             ...        ...         ...            ...
# 49995     740574175  740574175     15000.0        4614.28
# 49996     740574175  740574175     15000.0        4566.74
# 49997     740574175  740574175     15000.0        4190.99
# 49998     740574175  740574175     15000.0        4053.53
# 49999     740574175  740574175     15000.0        4024.21
#
#        transactionDateTime transactionAmount            merchantName  \
# 0      2016-01-20T19:00:48            352.62  Domino's Pizza #347016
# 1      2016-01-20T19:37:11             22.96              amazon.com
# ...

# %%
df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(2).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(100000,150000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(3).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(150000,200000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(4).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(200000,250000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(5).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(250000,300000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(6).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(300000,350000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(7).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(350000,400000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(8).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(400000,450000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(9).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(450000,500000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(10).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(500000,550000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(11).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(550000,600000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(12).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(600000,650000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(13).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(650000,700000):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(14).csv',encoding='utf-8',index=False)

# %%
df = pd.DataFrame(columns=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud'])

data_origin=pd.read_csv('transactions.csv',header=None)

data_origin=data_origin[[0]]

for i in range(700000,len(data_origin)):
    result=list(data_origin[0][i].strip('{',).strip('\n').strip('}').split(','))
    result.sort()

# result=[]
# result=list(line.strip('{',).strip('\n').split(','))
# result.sort()
    line_data = []    
    for i in range(len(result)):
        detail = result[i].split(':',1)
        line_data.append(detail[1])
        
    df = df.append([{'accountNumber':eval(line_data[28]),'accountOpenDate':eval(line_data[0]),'acqCountry':eval(line_data[1]), 'availableMoney':line_data[2],
                     'cardCVV':eval(line_data[3]),'cardLast4Digits':eval(line_data[4]),'cardPresent':line_data[5],'creditLimit':line_data[6],
                     'currentBalance':line_data[7],'currentExpDate':eval(line_data[8]),'customerId':eval(line_data[9]),
                     'dateOfLastAddressChange':eval(line_data[10]),'echoBuffer':eval(line_data[11]),'enteredCVV':eval(line_data[12]),
                     'expirationDateKeyInMatch':line_data[13],'isFraud':line_data[13],'merchantCategoryCode':line_data[13],
                     'merchantCity':eval(line_data[16]),'merchantCountryCode':eval(line_data[17]),'merchantName':eval(line_data[18]),
                     'merchantState':eval(line_data[19]),'merchantZip':eval(line_data[20]),'posConditionCode':eval(line_data[21]),
                     'posEntryMode':eval(line_data[22]),'posOnPremises':eval(line_data[23]),'recurringAuthInd':eval(line_data[24]),
                     'transactionAmount':line_data[25],'transactionDateTime':eval(line_data[26]),'transactionType':eval(line_data[27])}],ignore_index=True)

    df_name=['accountNumber', 'customerId', 'creditLimit', 'availableMoney','transactionDateTime','transactionAmount',
                          'merchantName','acqCountry','merchantCountryCode','posEntryMode','posConditionCode','merchantCategoryCode',
                          'currentExpDate','accountOpenDate','dateOfLastAddressChange','cardCVV','enteredCVV','cardLast4Digits',
                          'transactionType','echoBuffer','currentBalance','merchantCity','merchantState','merchantZip','cardPresent',
                          'posOnPremises','recurringAuthInd','expirationDateKeyInMatch','isFraud']
output_df=pd.DataFrame(columns=df_name,data=df)
output_df.to_csv('data challenge 2(15).csv',encoding='utf-8',index=False)
